# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline
DATA_FOLDER = '/home/azuredwp08/data/haystack/'

import pandas as pd
import pandas_profiling as pdp
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import re

pd.set_option('display.max_columns', 150)

# %%
df = pd.read_csv(DATA_FOLDER + 'scenario5/haystack_email.csv')
df['date'] = pd.to_datetime(df['date'], format='%m/%d/%Y %H:%M:%S')
df.head()
# Out:
#   activity attachments  bcc                                cc  \
# 0     Send         NaN  NaN            Mary.Bo.Greer@dtaa.com
# 1     Send         NaN  NaN                     LSK56@cox.net
# 2     Send         NaN  NaN  Kenneth.Jackson.Nichols@dtaa.com
# 3  Receive         NaN  NaN                               NaN
# 4  Receive         NaN  NaN                   GPH35@gmail.com
#
#                                              content                date  \
# 0  term 3000 sometimes were distinguish sexes 114... 2011-05-27 12:28:32
# 1  Two days after the storm, many of the roads ha... 2011-05-23 09:37:44
# 2  day little time voyager 24 less extreme prospe... 2011-04-05 10:37:09
# 3  ahmose prince prince prince prince prince prin... 2010-12-28 13:24:23
# 4  initiating had key degree conference pre cours... 2010-04-08 11:33:12
#
#                                from                        id       pc   size  \
# 0            Mary.Bo.Greer@dtaa.com  {E1C6-M7EM35LA-4130GQLS}  PC-0562  25511
# 1                     LSK56@cox.net  {H6T2-X3RW38DQ-3805TDHY}  PC-9580  33284
# 2  Kenneth.Jackson.Nichols@dtaa.com  {R6Z4-W6BX24NX-9621CGKZ}  PC-7696  35087
# 3       Conan.Galvin.Sweet@dtaa.com  {C7A7-K0XN51WO-0071HDVZ}  PC-0223  35313
# 4                  BDC9@netzero.com  {H6U2-S0AI77HG-9172VFHH}  PC-1576  29738
#
#                                                 to     user
# 0                    Zena.Xantha.Roberson@dtaa.com  MBG1455
# 1                          Church-Erasmus@juno.com  LSK2577
# 2                    Selma.Tatyana.Warner@dtaa.com  KJN0240
# 3                      Adrian.Brett.Lewis@dtaa.com  ABL1229
# 4  Medge_Hayden@hotmail.com;Adam.C.Haney@gmail.com  BDC0936

# %%
lg_df = pd.read_csv(DATA_FOLDER + 'scenario5/haystack_logon.csv')
lg_df['date'] = pd.to_datetime(df['date'], format='%m/%d/%Y %H:%M:%S')
lg_df.head()
# Out:
#                          id                date     user       pc activity
# 0  {K1Q6-O5MP41BQ-6513CGUG} 2011-05-27 12:28:32  ZJA2373  PC-9316    Logon
# 1  {T1P1-S4UI62CV-3014WHGU} 2011-05-23 09:37:44  COP0049  PC-0205    Logon
# 2  {Y2M3-O5DA18YV-5153LXFM} 2011-04-05 10:37:09  BNT0663  PC-6409    Logon
# 3  {I1Z6-T2UG40LY-7701JZWL} 2010-12-28 13:24:23  BBS0039  PC-8144    Logon
# 4  {C5X4-E2GB11MB-0804IKCY} 2010-04-08 11:33:12  ZEH0685  PC-8921    Logon

# %% [markdown]
# ### We may want to impute activity TODO

# %% [markdown]
# ### Filter the duplicate user IDs users

# %%
df[df['user'].isin(['BTR0403', 'CKR1700', 'SSH1780'])]
# Out:
#         activity                                        attachments  \
# 1351     Receive                                                NaN
# 1866        Send                                                NaN
# 1982     Receive                                                NaN
# 3284        View                                                NaN
# 4692        View  C:\HSW0946\9PTNG32U.pdf(822560);C:\ZI27REMH.do...
# 6127        View                                                NaN
# 6439        View                                                NaN
# 8573        Send                                                NaN
# 8944        Send                                                NaN
# 11191    Receive                                                NaN
# 13191    Receive                                                NaN
# 13905       View                                                NaN
# 17794    Receive                                                NaN
# 18398       Send                                      8.txt(627310)
# 22288       Send                                                NaN
# 24371       Send                                 among.jpg(1383225)
# 25122       Send                                                NaN
# 25914        NaN                                                  0
# 29309    Receive                                                NaN
# 29863       Send                                                NaN
# 30117        NaN                                                  1
# 33744    Receive                                                NaN
# 35940    Receive                                                NaN
# 40765       Send                                                NaN
# 42515       Send                                                NaN
# 43995    Receive  1997.zip(1156808);exploded.zip(195588);focus.e...
# 45407    Receive                                                NaN
# 45865       View                                                NaN
# 46052    Receive                                premise.txt(570007)
# 47347       View                                                NaN
# ...          ...                                                ...
# 1502638     Send                                                NaN
# 1502850     View                                                NaN
# 1503454  Receive                                                NaN
# 1504123     View                                                NaN
# 1505151     Send                                                NaN
# 1505606     Send                                                NaN
# 1509731     Send                                                NaN
# 1511667      NaN                                                  0
# 1512193      NaN                                                  0
# 1513196  Receive                                                NaN
# 1514321     Send                                                NaN
# 1514504     Send                                                NaN
# 1515006  Receive                                                NaN
# 1515212     View  C:\EAF2385\5GCW775O.doc(1047897);C:\EAF2385\N1...
# 1518006  Receive                                                NaN
# 1518018     Send                                                NaN
# 1519054  Receive               plays.txt(284592);pieces.doc(944144)
# 1520167      NaN                                                  0
# 1521079     Send                                                NaN
# 1522888  Receive                                  1966.txt(1094633)
# 1527678     View  C:\818djj8\YOZ2X9HZ.doc(1550521);C:\VDG6Q87H.p...
# 1527845  Receive                                  down.exe(1219751)
# 1531482      NaN                                                  0
# 1533080  Receive                                                NaN
# 1535825      NaN                                                  0
# 1538355     Send                                                NaN
# 1538920  Receive                                                NaN
# 1539227  Receive                                                NaN
# 1540123  Receive                                                NaN
# 1540621     Send                                                NaN
#
#                                  bcc  \
# 1351                             NaN
# 1866                             NaN
# 1982                             NaN
# 3284                             NaN
# 4692                             NaN
# 6127                             NaN
# 6439                             NaN
# 8573                             NaN
# 8944                             NaN
# 11191                            NaN
# 13191                            NaN
# 13905                            NaN
# 17794                            NaN
# 18398                            NaN
# 22288                            NaN
# 24371                            NaN
# 25122                            NaN
# 25914    Beck.Troy.Richards@dtaa.com
# 29309                            NaN
# 29863                            NaN
# 30117    Beck.Troy.Richards@dtaa.com
# 33744                            NaN
# 35940                            NaN
# 40765                            NaN
# 42515                            NaN
# 43995                            NaN
# 45407                            NaN
# 45865                            NaN
# 46052                            NaN
# 47347                            NaN
# ...                              ...
# 1502638                          NaN
# 1502850                          NaN
# 1503454                          NaN
# 1504123                          NaN
# 1505151                          NaN
# 1505606                          NaN
# 1509731                          NaN
# 1511667                          NaN
# 1512193       Richards-Beck@juno.com
# 1513196                          NaN
# 1514321                          NaN
# 1514504                          NaN
# 1515006                          NaN
# 1515212                          NaN
# 1518006                          NaN
# 1518018                          NaN
# 1519054                          NaN
# 1520167                          NaN
# 1521079                          NaN
# 1522888                          NaN
# 1527678                          NaN
# 1535825                    Jeanette.Eliana.Rivera@dtaa.com  BTR0403
# 1538355                      Aquila.William.Keith@dtaa.com  SSH1780
# 1538920  Ivy.Dahlia.Cantu@dtaa.com;Quinn.Dana.Bradshaw@...  SSH1780
# 1539227  Seth.Simon.Hicks@dtaa.com;Warren.Alfonso.Harpe...  SSH1780
# 1540123                          Seth.Simon.Hicks@dtaa.com  SSH1780
# 1540621                        Dara.Olympia.Klein@dtaa.com  BTR0403
#
# [969 rows x 12 columns]

# %%
# d = df[df['activity'] == 'Send']
# d[d['user'] == 'SSH1780']

# %%
df = df[~df['user'].isin(['BTR0403', 'CKR1700', 'SSH1780'])]

# %%
df.shape
# Out:
# (1541792, 12)

# %% [markdown]
# ### Construct features

# %%
def get_email_interactions(g):
    my_emails = g[g['activity'] == 'Send']['from'].unique()

    all_emails = []

    all_emails.extend(e for e in g['from'].values if e not in my_emails)

    g_sent = g[g['activity'] == 'Send']
    all_emails.extend(e for l in g_sent['to'].str.split(';').values for e in l if e not in my_emails)
    all_emails.extend(e for l in g_sent['cc'].dropna().str.split(';').values for e in l if e not in my_emails)
    all_emails.extend(e for l in g_sent['bcc'].dropna().str.split(';').values for e in l if e not in my_emails)

    all_emails = pd.Series(all_emails).value_counts()
    all_emails = all_emails/all_emails.sum()
    return my_emails, all_emails

sr = get_email_interactions(first_group)[1]
# sr

# %%
counter = 0

def _create_features(g):
    global counter
    counter += 1
    if counter % 100 == 0:
        print('Progress: {}'.format(counter))
    
    whole_g = g
    
    user = g.name
    print(user)
    
    # filter to send activity - TODO think about View activity as well?
    g = g[g['activity'] == 'Send']
    
    # is it sent from personal email?
    g['ft_pers_email'] = g['from'].apply(lambda x: x.endswith('@dtaa.com')).astype(int)
    
    ###############
    # DATE stuff
    ###############
    
    # minute of day
    g['ft_minute'] = g['date'].dt.hour*60 + g['date'].dt.minute  
    
    # number of days since first email - TODO - maybe since prev email?
    min_date = g['date'].min()
    g['ft_date'] = g['date'].apply(lambda d: (d - min_date).days)
    
    # is working day?
    g['ft_weekend'] = (g['date'].dt.dayofweek >= 5).astype(int)
    
    ###############
    # ATTACHMENTS/SIZE
    ###############
    
    # number of attachments
    g['ft_no_attach'] = g['attachments'].apply(lambda x: len(x.split(';')) if pd.notnull(x) else 0)
    
    # size of attachments
    g['ft_attach_size'] = g['attachments'].apply(lambda x: sum(
        int(m) for m in re.findall(r'\((\d+)\)', x)
    ) if pd.notnull(x) else 0)
    
    # the rest of the email size
    g['ft_text_size'] = g['size'] - g['ft_attach_size']
    
    ###############
    # LINKS
    ###############
    
    # avg. strength of links with people included in the email
    my_emails, email_interactions = get_email_interactions(whole_g)
    g['all_emails'] = g['to'].str.split(';') + g['cc'].fillna('').str.split(';') + g['bcc'].fillna('').str.split(';')
    def _get_score(emails):
        emails = [e for e in emails if e not in my_emails and e != '']
        
        if len(emails) == 0:
            return None
            
        return sum(email_interactions[e] for e in emails)/len(emails)
    g['ft_interact_score'] = g['all_emails'].apply(_get_score)
    g['ft_interact_score'] = g['ft_interact_score'].fillna(g['ft_interact_score'].mean())
    
    g['ft_number_recipients'] = g['all_emails'].apply(len)
    
    ###############
    # LOGON/LOGOFF
    ###############
    
    lg = lg_df[lg_df['user'] == user]
    lg_on = list(lg[lg['activity'] == 'Logon']['date'].sort_values())
    lg_off = list(lg[lg['activity'] == 'Logoff']['date'].sort_values())
    
    cur_on_i = 0
    cur_off_i = 0
    latest_lg_on = {}
    earliest_lg_off = {}
    for i, date in g['date'].sort_values().items():
        while cur_on_i < len(lg_on) and lg_on[cur_on_i] <= date:
            cur_on_i += 1
            
        if cur_on_i > 0:
            latest_lg_on[i] = lg_on[cur_on_i - 1]
        
        while cur_off_i < len(lg_off) and lg_off[cur_off_i] < date:
            cur_off_i += 1
            
        if cur_off_i < len(lg_off):
            earliest_lg_off[i] = lg_off[cur_off_i]
    
#     g['ft_latest_logon'] = pd.Series(latest_lg_on)
#     g['ft_earliest_logoff'] = pd.Series(earliest_lg_off)

    ###############
    # CONTENT
    ###############
    
    all_content = ' '.join(g['content'])

    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(g['content'])
    feature_names = np.array(vectorizer.get_feature_names())

    mean_tfidfs = []
    top_tfidfs = []
    no_diff_words = []
    avg_word_length = []
    for i in range(X.shape[0]):
        x = X[i]
        
        words = feature_names[x.toarray()[0] != 0]
        
        x = x[x != 0]
        
        mean_tfidfs.append(x.mean())
        top_tfidfs.append(np.quantile(x, 0.9))
        no_diff_words.append(x.shape[1])
        avg_word_length.append(np.array([len(w) for w in words]).mean())
        
    g['ft_mean_tfidf'] = mean_tfidfs
    g['ft_top_tfidf'] = top_tfidfs
    g['ft_no_diff_words'] = no_diff_words
    g['ft_vocal_variety'] = g['ft_no_diff_words'] / g['content'].str.split(' ').apply(len)
    g['ft_word_lengths'] = avg_word_length
    
    
    ng_vectorizer = TfidfVectorizer(ngram_range=(2,2))
    ng_X = ng_vectorizer.fit_transform(g['content'])
    
    ng_mean_tfidfs = []
    for i in range(ng_X.shape[0]):
        x = ng_X[i]
        x = x[x != 0]
        
        ng_mean_tfidfs.append(x.mean())
        
    g['ft_ng_mean_tfidf'] = ng_mean_tfidfs   
    
#     return g
    return g[[c for c in g.columns if c.startswith('ft_')]]

ftdf = df.groupby('user').apply(_create_features)
# Out:
# AAA1182
# AAA1182
# AAB1302
# AAB1762
# AAB3987
# AAC0131
# AAC0599
# AAC0904
# AAC1033
# AAC1489
# AAC1881
# AAE0190
# AAA1182
# AAB1302
# AAB1762
# AAB3987
# AAC0131
# AAC0599
# AAC0904
# AAC1033
# AAC1489
# AAC1881
# AAE0190
# AAA1182
# AAA1182
# AAB1302
# AAB1762
# AAB3987
# AAC0131
# AAC0599
# AAC0904
# AAC1033
# AAC1489
# AAC1881
# AAE0190
# AAA1182
# AAB1302
# AAB1762
# AAB3987
# AAC0131
# AAC0599
# AAC0904
# AAC1033
# AAC1489
# AAC1881
# AAE0190
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# <ipython-input-253-b51815040d63> in _create_features(g)
#     102     vectorizer = TfidfVectorizer()
# --> 103     X = vectorizer.fit_transform(g['content'])
#     104     feature_names = np.array(vectorizer.get_feature_names())
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1380         """
# -> 1381         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1382         self._tfidf.fit(X)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     810             if not vocabulary:
# --> 811                 raise ValueError("empty vocabulary; perhaps the documents only"
#     812                                  " contain stop words")
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-253-b51815040d63> in <module>()
#     142     return g[[c for c in g.columns if c.startswith('ft_')]]
#     143
# --> 144 ftdf = df.groupby('user').apply(_create_features)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# <ipython-input-253-b51815040d63> in _create_features(g)
#     101
#     102     vectorizer = TfidfVectorizer()
# --> 103     X = vectorizer.fit_transform(g['content'])
#     104     feature_names = np.array(vectorizer.get_feature_names())
#     105
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1379             Tf-idf-weighted document-term matrix.
#    1380         """
# -> 1381         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1382         self._tfidf.fit(X)
#    1383         # X is already a transformed view of raw_documents so
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     809             vocabulary = dict(vocabulary)
#     810             if not vocabulary:
# --> 811                 raise ValueError("empty vocabulary; perhaps the documents only"
#     812                                  " contain stop words")
#     813
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
df[df['user'] == 'AAE0190']
# Out:
#         activity attachments  bcc  \
# 1458         NaN           1  NaN
# 6026         NaN           0  NaN
# 16287        NaN           0  NaN
# 27601        NaN           0  NaN
# 35441        NaN           6  NaN
# 36602        NaN           0  NaN
# 42119        NaN           0  NaN
# 56488        NaN           0  NaN
# 57779        NaN           0  NaN
# 58505        NaN           0  NaN
# 62439        NaN           0  NaN
# 66243        NaN           0  NaN
# 71233        NaN           1  NaN
# 78692        NaN           0  NaN
# 79510        NaN           0  NaN
# 81219        NaN           0  NaN
# 103680       NaN           1  NaN
# 105965       NaN           0  NaN
# 113544       NaN           0  NaN
# 114516       NaN           0  NaN
# 115661       NaN           0  NaN
# 123438       NaN           0  NaN
# 133037       NaN           0  NaN
# 134192       NaN           0  NaN
# 136375       NaN           0  NaN
# 162456       NaN           0  NaN
# 192686       NaN           1  NaN
# 198821       NaN           1  NaN
# 201062       NaN           2  NaN
# 202955       NaN           0  NaN
# ...          ...         ...  ...
# 1364158      NaN           0  NaN
# 1365763      NaN           0  NaN
# 1367407      NaN           0  NaN
# 1368021      NaN           0  NaN
# 1381490      NaN           1  NaN
# 1385921      NaN           0  NaN
# 1390696      NaN           0  NaN
# 1394561      NaN           2  NaN
# 1397117      NaN           0  NaN
# 1404353      NaN           0  NaN
# 1415752      NaN           0  NaN
# 1421792      NaN           0  NaN
# 1422331      NaN           0  NaN
# 1432991      NaN           0  NaN
# 1441819      NaN           0  NaN
# 1444820      NaN           0  NaN
# 1448962      NaN           0  NaN
# 1450135      NaN           0  NaN
# 1472919      NaN           0  NaN
# 1486195      NaN           1  NaN
# 1501661      NaN           1  NaN
# 1503892      NaN           1  NaN
# 1504384      NaN           0  NaN
# 1505033      NaN           0  NaN
# 1510824      NaN           0  NaN
# 1511283      NaN           0  NaN
# 1519420      NaN           0  NaN
# 1520965      NaN           0  NaN
# 1531645      NaN           0  NaN
# 1540702      NaN           0  NaN
#
#                                                         cc  \
# 1458     Sawyer.Abel.Turner@dtaa.com;Kirby.Bo.Pollard@d...
# 6026                                                   NaN
# 16287                                                  NaN
# 27601                                                  NaN
# 35441                        Sawyer.A.Turner@sbcglobal.net
# 36602                                                  NaN
# 1394561  Callum.Scott.Parrish@dtaa.com;Whoopi.Britanney...  AAE0190
# 1397117                     Tarik.Odysseus.Rivera@dtaa.com  AAE0190
# 1404353  Yolanda.I.Crosby@juno.com;Sawyer.A.Turner@sbcg...  AAE0190
# 1415752                  Deborah.Victoria.Mcclure@dtaa.com  AAE0190
# 1421792                        Kaye.Brianna.Blair@dtaa.com  AAE0190
# 1422331                 Eugenia.W.Harrington@bellsouth.net  AAE0190
# 1432991                      Yolanda.Idona.Crosby@dtaa.com  AAE0190
# 1441819                      Yolanda.Idona.Crosby@dtaa.com  AAE0190
# 1444820                         Hadley.S.Bowen@charter.net  AAE0190
# 1448962                             Rivera-Tarik@yahoo.com  AAE0190
# 1450135  Kirby.Bo.Pollard@dtaa.com;Jorden.Helen.Pierce@...  AAE0190
# 1472919  Kirby.B.Pollard@juno.com;Hadley.S.Bowen@charte...  AAE0190
# 1486195              Eugenia.Whilemina.Harrington@dtaa.com  AAE0190
# 1501661  Yolanda.I.Crosby@juno.com;Kirby.B.Pollard@juno...  AAE0190
# 1503892  Rivera-Tarik@yahoo.com;Sawyer.A.Turner@sbcglob...  AAE0190
# 1504384  Hadley.Sonya.Bowen@dtaa.com;Jena.Chanda.Rollin...  AAE0190
# 1505033  Kirby.Bo.Pollard@dtaa.com;Eugenia.Whilemina.Ha...  AAE0190
# 1510824                      Sawyer.A.Turner@sbcglobal.net  AAE0190
# 1511283  Whoopi.B.Camacho@aol.com;Sawyer.A.Turner@sbcgl...  AAE0190
# 1519420  Sawyer.Abel.Turner@dtaa.com;Tarik.Odysseus.Riv...  AAE0190
# 1520965                             Rivera-Tarik@yahoo.com  AAE0190
# 1531645  Kaye.Brianna.Blair@dtaa.com;Sawyer.Abel.Turner...  AAE0190
# 1540702  Eugenia.Whilemina.Harrington@dtaa.com;Tarik.Od...  AAE0190
#
# [239 rows x 12 columns]

# %%
pd.isnull(df['activity']).sum()

# %%
df[pd.isnull(df['activity'])['user'].nunique()

# %%
df['activity'].count()/len(df)
# Out:
# 0.9104172287831303

# %%
df['user'].nunique()
# Out:
# 6838

# %%
d['ft_vocal_variety'].plot.hist()

# %%
d.plot.scatter('ft_mean_tfidf', 'ft_top_tfidf')

# %%
lg_df[lg_df['user'] == 'MBG1455'].sort_values(by='date')
# Out:
#                               id                date     user       pc  \
# 287212  {S8L3-L5IS27WU-1174DXRM} 2010-01-06 16:50:34  MBG1455  PC-0562
# 8746    {C2A5-B7HX13MC-0976LBCM} 2010-01-07 09:42:37  MBG1455  PC-0562
# 580695  {S0N8-L2AZ81MQ-5837MYOI} 2010-02-01 15:40:12  MBG1455  PC-0562
# 145126  {H6B2-R9VA12BA-4133XXZL} 2010-02-02 14:37:13  MBG1455  PC-0562
# 498949  {M2K0-E3JP76FC-4976NTKT} 2010-02-03 18:44:44  MBG1455  PC-0562
# 214734  {Q5J1-O6QP63DH-5233BOEF} 2010-03-04 19:36:24  MBG1455  PC-0562
# 566231  {V5W4-C4GL18GU-5054YYXZ} 2010-03-16 15:39:27  MBG1455  PC-0562
# 56860   {X1X6-K8UD27PP-5049PAEP} 2011-01-14 11:19:23  MBG1455  PC-0562
# 321399  {E7Z0-H7NI50XG-2593YGSU} 2011-01-21 10:05:23  MBG1455  PC-0562
# 236252  {M2B7-G6MD00DM-4609HTGA} 2011-01-31 15:42:19  MBG1455  PC-0562
# 419882  {O5D9-T8IC91FQ-3984BWAE} 2011-02-04 14:52:39  MBG1455  PC-0562
# 287741  {Y5R7-F8VP90FM-0613OVHB} 2011-02-15 08:49:55  MBG1455  PC-0562
# 102752  {X6E6-F4GG05GJ-8630DVGS} 2011-02-18 14:43:01  MBG1455  PC-0562
# 586311  {N6V0-U1TD17NB-5355NBRE} 2011-03-01 15:56:28  MBG1455  PC-0562
# 55894   {S4M7-I9PU46MG-6240GLLS} 2011-03-09 09:23:00  MBG1455  PC-0562
# 670479  {B7R0-Q0DS56CG-5903EXQX} 2011-03-24 15:53:34  MBG1455  PC-0562
# 121532  {C0C2-R9XM45ED-8797LRXS} 2011-03-25 13:47:58  MBG1455  PC-0562
# 221043  {P1Z8-K6KS15OT-9235TVOK} 2011-03-28 10:38:04  MBG1455  PC-0562
# 362180  {Y1P3-T3BC82VO-3812HFLR} 2011-04-04 11:21:45  MBG1455  PC-0562
# 53372   {B2O2-U3ES94NT-1438KBJT} 2011-04-08 14:38:37  MBG1455  PC-0562
# 193895  {H4Q9-Q6KD82FM-7274IITJ} 2011-04-10 11:52:48  MBG1455  PC-0562
# 211055  {A0W8-W6GC84OO-5016UPBP} 2011-04-13 10:51:31  MBG1455  PC-0562
# 24353   {W9C4-U0VI05SP-4080MFFU} 2011-04-25 08:06:00  MBG1455  PC-0562
# 208456  {F8O4-B1CT13MJ-8728GPKX} 2011-04-25 13:15:59  MBG1455  PC-0562
# 308833  {J2L2-Y0NQ63GC-8178IAOE} 2011-05-10 15:15:52  MBG1455  PC-0562
# 200823  {F2N2-P3FW44VA-8492CPAP} 2011-05-13 10:52:05  MBG1455  PC-0562
# 256985  {Q2J2-E0UI08WS-8767SOSJ} 2011-05-26 10:01:27  MBG1455  PC-0562
# 434841  {A6J0-R7SN01IH-9010CDVY} 2011-05-31 13:01:49  MBG1455  PC-0562
#
#        activity
# 287212   Logoff
# 8746     Logoff
# 580695    Logon
# 145126    Logon
# 498949   Logoff
# 214734   Logoff
# 566231    Logon
# 324776   Logoff
# 23712    Logoff
# 637146    Logon
# 198451   Logoff
# 126059    Logon
# 418583    Logon
# 425879   Logoff
# 671485   Logoff
# 72024    Logoff
# 654008   Logoff
# 511929    Logon
# 105602   Logoff
# 490500    Logon
# 251685    Logon
# 9646     Logoff
# 115464    Logon
# 498656   Logoff
# 615439   Logoff
# 31428    Logoff
# 676836   Logoff
# 631081    Logon
# 656814   Logoff
# 169328    Logon
# 587284    Logon
# 585994    Logon
# 527693   Logoff
# 530587    Logon
# 275774    Logon
# 559611    Logon
# 129840   Logoff
# 56860     Logon
# 321399    Logon
# 236252    Logon
# 419882    Logon
# 287741    Logon
# 102752    Logon
# 586311    Logon
# 55894    Logoff
# 670479   Logoff
# 121532    Logon
# 221043    Logon
# 362180    Logon
# 53372    Logoff
# 193895    Logon
# 211055    Logon
# 24353    Logoff
# 208456    Logon
# 308833    Logon
# 200823    Logon
# 256985   Logoff
# 434841    Logon

# %%
g['date'].
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-20c34fc2412d> in <module>()
# ----> 1 g['date'].first()
#
# TypeError: first() missing 1 required positional argument: 'offset'

# %%
next(g['date'].items())
# Out:
# (0, Timestamp('2011-05-27 12:28:32'))

# %%
lg_df['date'][0]
# Out:
# Timestamp('2011-05-27 12:28:32')

# %%
user = g['user'].iloc[0]

lg = lg_df[lg_df['user'] == user]
lg_on = lg[lg['activity'] == 'Logon'].sort_values(by='date')
lg_off = lg[lg['activity'] == 'Logoff'].sort_values(by='date')

lg_on['date']
# Out:
#                               id                date     user       pc  \
# 580695  {S0N8-L2AZ81MQ-5837MYOI} 2010-02-01 15:40:12  MBG1455  PC-0562
# 145126  {H6B2-R9VA12BA-4133XXZL} 2010-02-02 14:37:13  MBG1455  PC-0562
# 566231  {V5W4-C4GL18GU-5054YYXZ} 2010-03-16 15:39:27  MBG1455  PC-0562
# 637146  {L7F8-J0KD96SE-7890QCNZ} 2010-03-30 12:05:57  MBG1455  PC-0562
# 126059  {A4J4-Z7GJ95SN-7308PWTV} 2010-04-13 14:58:06  MBG1455  PC-0562
# 418583  {W9M2-W3TJ55AU-6081KVIZ} 2010-04-14 14:28:00  MBG1455  PC-0562
# 511929  {J3N8-D2UN90IL-4505YHRE} 2010-06-17 14:44:58  MBG1455  PC-0562
# 490500  {I9P5-G1AI01KI-2705PYRW} 2010-06-23 09:41:13  MBG1455  PC-0562
# 251685  {S0W9-H3RZ96AY-9036FFTS} 2010-07-06 09:53:05  MBG1455  PC-0562
# 115464  {V1J5-C4WB37ZN-1603LLSY} 2010-07-23 10:51:04  MBG1455  PC-0562
# 631081  {X8O0-H6OZ27LO-5165MNAS} 2010-09-10 12:16:42  MBG1455  PC-0562
# 169328  {P0K7-H0IW44RC-1823CFUD} 2010-11-23 07:41:25  MBG1455  PC-0562
# 587284  {A3C9-Q8TK63VH-8874FCRG} 2010-12-06 12:46:24  MBG1455  PC-0562
# 585994  {C9E1-E9SC95ER-6685LJTS} 2010-12-11 13:35:05  MBG1455  PC-0562
# 530587  {P9B6-A8EH71DY-8099BLRL} 2010-12-22 14:53:23  MBG1455  PC-0562
# 275774  {W1Y4-G2JM21UN-5112DYAH} 2010-12-29 09:25:25  MBG1455  PC-0562
# 559611  {M3D5-S0UY03TO-0502ZNTE} 2011-01-04 13:38:45  MBG1455  PC-0562
# 56860   {X1X6-K8UD27PP-5049PAEP} 2011-01-14 11:19:23  MBG1455  PC-0562
# 321399  {E7Z0-H7NI50XG-2593YGSU} 2011-01-21 10:05:23  MBG1455  PC-0562
# 236252  {M2B7-G6MD00DM-4609HTGA} 2011-01-31 15:42:19  MBG1455  PC-0562
# 419882  {O5D9-T8IC91FQ-3984BWAE} 2011-02-04 14:52:39  MBG1455  PC-0562
# 287741  {Y5R7-F8VP90FM-0613OVHB} 2011-02-15 08:49:55  MBG1455  PC-0562
# 679391  {F5L5-S6CS19GY-7657NXGV} 2010-11-19 20:38:00  CLG0516  PC-7104
# 679392  {V1V2-Q0VV96KA-1463NKQW} 2010-08-13 16:11:56  GJB2659  PC-5426
# 679393  {F5K8-W3OS54TS-3811HZZM} 2010-01-25 07:26:00  RPC0464  PC-5810
# 679394  {C8Z1-T7AN76KY-1928RUET} 2010-03-30 10:25:07  CNK1726  PC-3030
# 679395  {H3T2-R4WM04HS-0731VXII} 2010-09-15 17:30:47  DRP2145  PC-0836
# 679396  {N4D3-F9SM20HW-7003PVXG} 2010-10-14 10:18:55  VAH2424  PC-5330
# 679397  {X8N8-B3ST31MW-1639YJRD} 2011-04-27 17:26:07  HPS3550  PC-3059
# 679398  {J0D6-D2KR42WY-0802OWCZ} 2010-05-21 08:53:43  NCT1153  PC-2726
# 679399  {E5L5-Q8GF41DP-8124THOE} 2010-10-15 09:15:06  SCL0022  PC-3317
# 679400  {O2N0-K9HI53KU-5548PHDM} 2011-03-18 08:29:13  PRH2431  PC-6980
# 679401  {N1F2-P9UP62CQ-8056KMND} 2010-11-09 08:56:20  KCR0577  PC-2870
# 679402  {U5O6-X3LF54TJ-9321ONSQ} 2010-07-28 09:52:53  JCR0398  PC-8553
# 679403  {S5C2-E3CC01TR-4410HFBR} 2010-04-23 13:20:37  JMW0638  PC-1397
# 679404  {B2A1-X8KS48GF-8414XJZE} 2010-07-20 12:34:42  DJL0908  PC-5730
# 679405  {N8G9-I7VH72EB-4425DKMM} 2010-06-18 13:59:12  RLF0928  PC-0525
# 679406  {E7O5-I8OJ67QD-9109AYWQ} 2010-01-08 08:11:16  PBG1778  PC-1584
# 679407  {V3G0-K4WC73EM-7169ARQN} 2010-09-17 13:35:16  CAG2442  PC-3465
# 679408  {K7S8-N6SW64DB-8029IUNF} 2010-09-14 10:25:39  HKG1858  PC-5235
#
#        activity
# 0         Logon
# 1         Logon
# 2         Logon
# 3         Logon
# 4         Logon
# 5         Logon
# 6         Logon
# 7        Logoff
# 8         Logon
# 9         Logon
# 10       Logoff
# 11        Logon
# 12        Logon
# 13       Logoff
# 14       Logoff
# 15        Logon
# 16        Logon
# 17        Logon
# 18        Logon
# 19       Logoff
# 20        Logon
# 21       Logoff
# 22       Logoff
# 23       Logoff
# 24       Logoff
# 25        Logon
# 26        Logon
# 27        Logon
# 28        Logon
# 29        Logon
# ...         ...
# 679379   Logoff
# 679380    Logon
# 679381   Logoff
# 679382    Logon
# 679383   Logoff
# 679384   Logoff
# 679385   Logoff
# 679386    Logon
# 679387    Logon
# 679388   Logoff
# 679389   Logoff
# 679390    Logon
# 679391    Logon
# 679392   Logoff
# 679393    Logon
# 679394    Logon
# 679395    Logon
# 679396   Logoff
# 679397   Logoff
# 679398    Logon
# 679399   Logoff
# 679400   Logoff
# 679401    Logon
# 679402   Logoff
# 679403    Logon
# 679404   Logoff
# 679405   Logoff
# 679406    Logon
# 679407   Logoff
# 679408   Logoff
#
# [679409 rows x 5 columns]

# %%
g = re.search(r'\((\d+)\)', 'fsdfsd(13431432).docx')
g.group(1)
# Out:
# '13431432'
